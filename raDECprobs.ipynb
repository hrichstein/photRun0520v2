# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dire = 'catRawMags1305/catDir/'

psf1 = np.genfromtxt(dire+'psfDith1.dat',names=True)
my1 = np.genfromtxt(dire+'myDith1.dat',names=True)

psf234 = np.genfromtxt(dire+'psfDith234.dat',names=True)
my234 = np.genfromtxt(dire+'myDith234.dat',names=True)

# %%
coords = np.genfromtxt(dire+'HOROLOGIUM-I_F814W_at_long.dat',names=True)
coords1 = np.genfromtxt(dire+'HOROLOGIUM-I_F814W_at_long_DRCwcs.dat',names=True)

# %%
psfL = np.genfromtxt(dire+'psf.dat',names=True)
myL = np.genfromtxt(dire+'my.dat',names=True)

# %%
psfD = np.genfromtxt(dire+'psf_drc.dat',names=True)
myD = np.genfromtxt(dire+'my_drc.dat',names=True)

# %%
drcL = np.genfromtxt(dire+'drc_drcLast.dat',names=True)
myDrcL = np.genfromtxt(dire+'my_drcLast.dat',names=True)

# %%
dir1='/Volumes/Spare Data/Hannah_Data/mattia/rephotometryquestion/'
psf_file = np.genfromtxt(dir1 + 'HOROLOGIUM_CF.1.TOSEND.CAT',names=True)

# %%
dir2 = '/Volumes/Spare Data/photRun0520/catRawMags1305/catDir/'
my_file = np.genfromtxt(dir2+'HOROLOGIUM-I_F606W_at_long.dat')

# %%
dir3  = '/Users/hr8jz/Box Sync/Research/source_lists/june13/'
drc_file = np.genfromtxt(dir3 + 'HOROLOGIUM-I_sfErr.dat',names=True)

# %%
print(len(drc_file))
# Out:
# 1648

# %%
# Getting 100 brightest stars; argsort gives idx for sorted values from
# smallest to largest
drc_idx = np.argsort(drc_file['magRaw_i'])[:99]

drc_100 = drc_file[drc_idx]

# %%
psf_idx = np.argsort(psf_file['m814c'])[:99]
psf_100 = psf_file[psf_idx]

# %%
fig,ax = plt.subplots()

ax.scatter(psf1['ra'],psf1['dec'],label='PSF')
ax.scatter(my1['wcsRA'],my1['wcsDEC'],label='1')

ax.set_xlim(43.84,43.94)
ax.set_ylim(-54.16,-54.08)

ax.legend()

plt.show()

# %%
fig,ax = plt.subplots()

ax.scatter(psf234['ra'],psf234['dec'],label='PSF')
ax.scatter(my234['wcsRA'],my234['wcsDEC'],label='234')

ax.legend()

ax.set_xlim(43.84,43.94)
ax.set_ylim(-54.16,-54.08)

plt.show()

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,5),sharex=True,sharey=True)

ax1.scatter(psf1['ra'],psf1['dec'],label='PSF')
ax1.scatter(my1['wcsRA'],my1['wcsDEC'],label='1')

ax1.set_xlim(43.84,43.94)
ax1.set_ylim(-54.16,-54.08)

ax1.legend()

ax2.scatter(psf234['ra'],psf234['dec'],label='PSF')
ax2.scatter(my234['wcsRA'],my234['wcsDEC'],label='234')

ax2.legend()

plt.show()

# %%
fig,ax1 = plt.subplots(figsize=(6,5))

ax1.scatter(psfL['ra'],psfL['dec'],label='PSF')
ax1.scatter(myL['RA_f814w'],myL['DEC_f814w'],label='L')

ax1.set_xlim(43.84,43.94)
ax1.set_ylim(-54.16,-54.08)

ax1.legend()

# ax2.scatter(psf234['ra'],psf234['dec'],label='PSF')
# ax2.scatter(my234['wcsRA'],my234['wcsDEC'],label='234')

# ax2.legend()

plt.show()

# %%
fig,ax1 = plt.subplots(figsize=(6,5))

ax1.scatter(psfD['ra'],psfD['dec'],label='PSF')
ax1.scatter(myD['RA_i'],myD['DEC_i'],label='D')

# ax1.set_xlim(43.84,43.94)
# ax1.set_ylim(-54.16,-54.08)

ax1.set_xlim(43.88,43.90)
ax1.set_ylim(-54.12,-54.11)

ax1.legend()


plt.show()

# %%
fig,ax1 = plt.subplots(figsize=(6,5))

ax1.scatter(drcL['RA_i'],drcL['DEC_i'],label='DRC')
ax1.scatter(myDrcL['RA_f814w'],myDrcL['DEC_f814w'],label='L')

ax1.set_xlim(43.84,43.94)
ax1.set_ylim(-54.16,-54.08)

ax1.legend()


plt.show()

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,5),sharex=True,sharey=True)

ax1.scatter(coords['wra1c'],coords['wdec1c'],label='DC 1')
ax1.scatter(coords['wra2c'],coords['wdec2c'],label='DC 2')
ax1.scatter(coords['wra3c'],coords['wdec3c'],label='DC 3')
ax1.scatter(coords['wra4c'],coords['wdec4c'],label='DC 4')

# ax2.scatter(coords['wcsRA'],coords['wcsDEC'],label='WCS DRC')
# ax2.scatter(myDrcL['RA_f814w'],myDrcL['DEC_f814w'],label='L')
# ax2.scatter(coords['wra1c'],coords['wdec1c'],label='DC 1')




# ax1.set_xlim(43.84,43.94)
# ax1.set_ylim(-54.16,-54.08)

ax1.set_xlim(43.88,43.90)
ax1.set_ylim(-54.11,-54.12)

ax1.legend()


plt.show()

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,5),sharex=True,sharey=True)

ax1.scatter(coords['xc1'],coords['yc1'],label='DC 1')
ax1.scatter(coords['xc2'],coords['yc2'],label='DC 2')
ax1.scatter(coords['xc3'],coords['yc3'],label='DC 3')
ax1.scatter(coords['xc4'],coords['yc4'],label='DC 4')

# ax2.scatter(coords['wcsRA'],coords['wcsDEC'],label='WCS DRC')
# ax2.scatter(myDrcL['RA_f814w'],myDrcL['DEC_f814w'],label='L')
# ax2.scatter(coords['wra1c'],coords['wdec1c'],label='DC 1')




ax1.set_xlim(1500,2500)
ax1.set_ylim(2000,2500)

ax1.legend()


plt.show()

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(14,5),sharex=True,sharey=True)

ax1.scatter(coords['wcsRA'],coords['wcsDEC'],label='DC 1',color='indianred')
ax1.scatter(drc_100['RA_i'],drc_100['DEC_i'],label='DRC',color='silver')

ax2.scatter(drc_100['RA_i'],drc_100['DEC_i'],label='DRC',color='silver')
ax2.scatter(psf_100['ra'],psf_100['dec'],label='PSF',color='lightseagreen')

ax3.scatter(coords['wcsRA'],coords['wcsDEC'],label='DC 1',color='indianred')
ax3.scatter(psf_100['ra'],psf_100['dec'],label='PSF',color='lightseagreen')



ax1.set_xlim(43.84,43.94)
ax1.set_ylim(-54.16,-54.08)
# ax1.set_xlim(1500,2500)
# ax1.set_ylim(2000,2500)

ax1.legend()
ax2.legend()
ax3.legend()

plt.subplots_adjust(wspace=0)
plt.savefig('plots2105/DRC100brightest.png')
# plt.show()

# %%
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(12,12),sharex=True,sharey=True)


ax1.scatter(coords['xc1'],coords['yc1'],label='DC 1')
ax2.scatter(coords['xc2'],coords['yc2'],label='DC 2')
ax3.scatter(coords['xc3'],coords['yc3'],label='DC 3')
ax4.scatter(coords['xc4'],coords['yc4'],label='DC 4')

ax1.scatter(coords['xt1'],coords['yt1'],label='OC 1')
ax2.scatter(coords['xo2'],coords['yo2'],label='OC 2')
ax3.scatter(coords['xo3'],coords['yo3'],label='OC 3')
ax4.scatter(coords['xo4'],coords['yo4'],label='OC 4')


ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

plt.subplots_adjust(hspace=0,wspace=0)
plt.savefig('plots2105/offset_vs_dist.png')
# plt.show()

# %%
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(12,12),sharex=True,sharey=True)


ax1.scatter(coords['xc1'],coords['yc1'],label='DC 1')
ax2.scatter(coords['xt1'],coords['yt1'],label='OC 1')
ax3.scatter(coords['xt1'],coords['yt1'],label='OC 1')
ax4.scatter(coords['xt1'],coords['yt1'],label='OC 1')

ax1.scatter(coords['xt1'],coords['yt1'],label='OC 1')
ax2.scatter(coords['xo2'],coords['yo2'],label='OC 2')
ax3.scatter(coords['xo3'],coords['yo3'],label='OC 3')
ax4.scatter(coords['xo4'],coords['yo4'],label='OC 4')


ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

plt.subplots_adjust(hspace=0,wspace=0)
plt.savefig('plots2105/offset_acrossDiths.png')
plt.show()

# %%
fig,(ax1,ax2) = plt.subplots(1,2,sharex=True,sharey=True,figsize=(12,5))

ax1.scatter(coords['xt1'],coords['yt1'],label='OC 1',color='indianred')
ax1.scatter(coords['xo2'],coords['yo2'],label='OC 2',color='lightpink')
ax1.scatter(coords['xo3'],coords['yo3'],label='OC 3',color='turquoise')
ax1.scatter(coords['xo4'],coords['yo4'],label='OC 4',s=10,color='black')

ax2.scatter(coords['xo2'],coords['yo2'],label='OC 2',color='lightpink')
ax2.scatter(coords['xo4'],coords['yo4'],label='OC 4',color='black',s=10)

ax1.legend()
ax2.legend()

plt.subplots_adjust(wspace=0)

plt.savefig('plots2105/moreOffsets.png')
# plt.show()

# %%
fig,(ax1,ax2) = plt.subplots(1,2,sharex=True,sharey=True,figsize=(12,5))

ax1.scatter(coords['xt1'],coords['yt1'],label='OC 1',color='indianred')
ax1.scatter(coords['xo2'],coords['yo2'],label='OC 2',color='magenta')
ax1.scatter(coords['xo3'],coords['yo3'],label='OC 3',color='turquoise')
ax1.scatter(coords['xo4'],coords['yo4'],label='OC 4',s=10,color='seagreen')

ax2.scatter(coords['xt1'],coords['yt1'],label='OC 1',color='indianred')
ax2.scatter(coords['xo3'],coords['yo3'],label='OC 3',color='turquoise',s=10)

ax1.legend()
ax2.legend()

plt.subplots_adjust(wspace=0)

plt.savefig('plots2105/moreOffsets13.png')
plt.show()

# %%
names = coords.dtype.names

for cc, cors in enumerate(names):
    print('Name:{0}, Value:{1}'.format(names[cc],coords[0][cc]))
# Out:
# Name:wcsRA, Value:43.9344126
# Name:wcsDEC, Value:-54.1236251
# Name:flux, Value:938.541
# Name:flags, Value:2.0
# Name:c_star, Value:0.029
# Name:mag1, Value:26.7083
# Name:mag2, Value:26.6075
# Name:mag3, Value:26.5078
# Name:mag4, Value:26.7497
# Name:ra1, Value:43.9344327
# Name:dec1, Value:-54.1235736
# Name:ra2, Value:43.9344304
# Name:dec2, Value:-54.1235789
# Name:ra3, Value:43.9344042
# Name:dec3, Value:-54.1235721
# Name:ra4, Value:43.934444
# Name:dec4, Value:-54.1235739
# Name:xr1, Value:2324.7354
# Name:yr1, Value:59.049
# Name:xc1, Value:2328.1138
# Name:yc1, Value:60.5689
# Name:xt1, Value:2329.1704
# Name:yt1, Value:64.7008
# Name:xr2, Value:2326.2417
# Name:yr2, Value:61.5068
# Name:xc2, Value:2328.5055
# Name:yc2, Value:59.4352
# Name:xo2, Value:2331.9061
# Name:yo2, Value:61.2067
# Name:xr3, Value:2332.9509
# Name:yr3, Value:65.5115
# Name:xc3, Value:2330.0123
# Name:yc3, Value:62.051
# Name:xo3, Value:2328.5055
# Name:yo3, Value:59.4352
# ...

# %%
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(12,12),sharex=True,sharey=True)


ax1.scatter(coords['wra1c'],coords['wdec1c'],label='DC 1')
ax2.scatter(coords['wra2c'],coords['wdec2c'],label='DC 2')
ax3.scatter(coords['wra3c'],coords['wdec3c'],label='DC 3')
ax4.scatter(coords['wra4c'],coords['wdec4c'],label='DC 4')


ax1.scatter(coords['wra1o'],coords['wdec1o'],label='OC 1')
ax2.scatter(coords['wra2o'],coords['wdec2o'],label='OC 2')
ax3.scatter(coords['wra3o'],coords['wdec3o'],label='OC 3')
ax4.scatter(coords['wra4o'],coords['wdec4o'],label='OC 4')


ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

plt.subplots_adjust(hspace=0,wspace=0)
# plt.savefig('plots2105/dc_oc_coordsDiths.png')
plt.show()

# %%
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(12,12),sharex=True,sharey=True)



ax1.scatter(coords['wra1o'],coords['wdec1o'],label='OC 1')
ax2.scatter(coords['wra2o'],coords['wdec2o'],label='OC 2')
ax3.scatter(coords['wra3o'],coords['wdec3o'],label='OC 3')
ax4.scatter(coords['wra4o'],coords['wdec4o'],label='OC 4')


ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

plt.subplots_adjust(hspace=0,wspace=0)
# plt.savefig('plots2105/dc_oc_coordsDiths.png')
plt.show()

# %%
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(12,12),sharex=True,sharey=True)


ax1.scatter(coords['wra1o'],coords['wdec1o'],label='OC 1')
ax2.scatter(coords['wra2o'],coords['wdec2o'],label='OC 2')
ax3.scatter(coords['wra3o'],coords['wdec3o'],label='OC 3')
ax4.scatter(coords['wra4o'],coords['wdec4o'],label='OC 4')

ax1.scatter(coords1['wra1o'],coords1['wdec1o'],label='OC DRCwcs 1')
ax2.scatter(coords1['wra2o'],coords1['wdec2o'],label='OC DRCwcs 2')
ax3.scatter(coords1['wra3o'],coords1['wdec3o'],label='OC DRCwcs 3')
ax4.scatter(coords1['wra4o'],coords1['wdec4o'],label='OC DRCwcs 4')

# ax1.scatter(coords['wra1o'],coords['wdec1o'],label='OC 1')
# ax2.scatter(coords['wra2o'],coords['wdec2o'],label='OC 2')
# ax3.scatter(coords['wra3o'],coords['wdec3o'],label='OC 3')
# ax4.scatter(coords['wra4o'],coords['wdec4o'],label='OC 4')


ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

plt.subplots_adjust(hspace=0,wspace=0)
plt.savefig('plots2105/oc_coordsDithsDRCWCS.png')
# plt.show()

# %%
fig,(ax1,ax2) = plt.subplots(1,2,sharex=True,sharey=True,figsize=(12,5))

ax1.scatter(coords['wra1o'],coords['wdec1o'],label='OC 1',color='indianred')
ax1.scatter(coords['wra2o'],coords['wdec2o'],label='OC 2',color='magenta')
ax1.scatter(coords['wra3o'],coords['wdec3o'],label='OC 3',color='turquoise')
ax1.scatter(coords['wra4o'],coords['wdec4o'],label='OC 4',s=10,color='seagreen')

ax2.scatter(coords['wra1o'],coords['wdec1o'],label='OC 1',color='indianred')
ax2.scatter(coords['wra2o'],coords['wdec2o'],label='OC 3',color='turquoise',s=10)

ax1.legend()
ax2.legend()

plt.subplots_adjust(wspace=0)

# plt.savefig('plots2105/moreOffsets13.png')
plt.show()

# %%
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(12,12),sharex=True,sharey=True)


ax1.scatter(coords['wra1c'],coords['wdec1c'],label='DC 1')
ax2.scatter(coords['wra1o'],coords['wdec1o'],label='OC 1')
ax3.scatter(coords['wra1o'],coords['wdec1o'],label='OC 1')
ax4.scatter(coords['wra1o'],coords['wdec1o'],label='OC 1')

ax1.scatter(coords['wra1o'],coords['wdec1o'],label='OC 1')
ax2.scatter(coords['wra2o'],coords['wdec2o'],label='OC 2')
ax3.scatter(coords['wra3o'],coords['wdec3o'],label='OC 3')
ax4.scatter(coords['wra4o'],coords['wdec4o'],label='OC 4')


ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

plt.subplots_adjust(hspace=0,wspace=0)
plt.savefig('plots2105/offset_coordsDiths.png')
plt.show()

# %%
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(12,12),sharex=True,sharey=True)


ax1.scatter(coords1['wra1c'],coords1['wdec1c'],label='DC 1')
ax2.scatter(coords1['wra1o'],coords1['wdec1o'],label='OC 1')
ax3.scatter(coords1['wra1o'],coords1['wdec1o'],label='OC 1')
ax4.scatter(coords1['wra1o'],coords1['wdec1o'],label='OC 1')

ax1.scatter(coords1['wra1o'],coords1['wdec1o'],label='OC 1')
ax2.scatter(coords1['wra2o'],coords1['wdec2o'],label='OC 2')
ax3.scatter(coords1['wra3o'],coords1['wdec3o'],label='OC 3')
ax4.scatter(coords1['wra4o'],coords1['wdec4o'],label='OC 4')


ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

plt.subplots_adjust(hspace=0,wspace=0)
# plt.savefig('plots2105/offset_coordsDiths.png')
plt.show()

# %%
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(12,12),sharex=True,sharey=True)


ax1.scatter(coords['wra1o'],coords['wdec1o'],label='OC 1')
ax2.scatter(coords['wra1c'],coords['wdec1c'],label='DC 1')
ax3.scatter(coords['wra1c'],coords['wdec1c'],label='DC 1')
ax4.scatter(coords['wra1c'],coords['wdec1c'],label='DC 1')

ax1.scatter(coords['wra1c'],coords['wdec1c'],label='DC 1')
ax2.scatter(coords['wra2c'],coords['wdec2c'],label='DC 2')
ax3.scatter(coords['wra3c'],coords['wdec3c'],label='DC 3')
ax4.scatter(coords['wra4c'],coords['wdec4c'],label='DC 4')


ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

plt.subplots_adjust(hspace=0,wspace=0)
# plt.savefig('plots2105/dcCoordsDiths.png')
plt.show()

# %%
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(12,12),sharex=True,sharey=True)


ax1.scatter(coords1['wra1c'],coords1['wdec1c'],label='DC 1')
ax2.scatter(coords1['wra2c'],coords1['wdec2c'],label='DC 2')
ax3.scatter(coords1['wra3c'],coords1['wdec3c'],label='DC 3')
ax4.scatter(coords1['wra4c'],coords1['wdec4c'],label='DC 4')

ax1.scatter(coords1['wra1o'],coords1['wdec1o'],label='OC 1')
ax2.scatter(coords1['wra2o'],coords1['wdec2o'],label='OC 2')
ax3.scatter(coords1['wra3o'],coords1['wdec3o'],label='OC 3')
ax4.scatter(coords1['wra4o'],coords1['wdec4o'],label='OC 4')


ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

plt.subplots_adjust(hspace=0,wspace=0)
# plt.savefig('plots2105/dcCoordsDiths.png')
plt.show()

# %%
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(12,12),sharex=True,sharey=True)


ax1.scatter(coords1['wra1c'],coords1['wdec1c'],label='DC 1')
ax2.scatter(coords1['wra1c'],coords1['wdec1c'],label='DC 1')
ax3.scatter(coords1['wra1c'],coords1['wdec1c'],label='DC 1')
ax4.scatter(coords1['wra1c'],coords1['wdec1c'],label='DC 1')

ax1.scatter(coords1['wra1o'],coords1['wdec1o'],label='OC 1')
ax2.scatter(coords1['wra2o'],coords1['wdec2o'],label='OC 2')
ax3.scatter(coords1['wra3o'],coords1['wdec3o'],label='OC 3')
ax4.scatter(coords1['wra4o'],coords1['wdec4o'],label='OC 4')


ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

plt.subplots_adjust(hspace=0,wspace=0)
# plt.savefig('plots2105/dcCoordsDiths.png')
plt.show()

# %%
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(12,12),sharex=True,sharey=True)


ax1.scatter(coords['wra1c'],coords['wdec1c'],label='DC 1')
ax2.scatter(coords['wra1c'],coords['wdec1c'],label='DC 1')
ax3.scatter(coords['wra1c'],coords['wdec1c'],label='DC 1')
ax4.scatter(coords['wra1c'],coords['wdec1c'],label='DC 1')

ax1.scatter(coords['wra1o'],coords['wdec1o'],label='OC 1')
ax2.scatter(coords['wra2o'],coords['wdec2o'],label='OC 2')
ax3.scatter(coords['wra3o'],coords['wdec3o'],label='OC 3')
ax4.scatter(coords['wra4o'],coords['wdec4o'],label='OC 4')


ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

plt.subplots_adjust(hspace=0,wspace=0)
# plt.savefig('plots2105/dcCoordsDiths.png')
plt.show()
