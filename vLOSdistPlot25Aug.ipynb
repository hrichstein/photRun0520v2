# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# # Distance and los velocity

# names = ['aqr2','boo1','boo2','boo4','cvn1','cvn2','car1','car2',\
# 'car3','cen1',\
# 'cet2','cet3','col1','comb1','crat2','dra1','dra2','eri2','eri3',\
# 'forn','grus1','grus2','herc','hor1','hor2','hya2','hyi1','ind2',\
# 'leo1','leo2','leo4','leov','lmc','peg3','phe1','phe2','pic2','pic1',\
# 'psc2','ret2','ret3','scu','seg1','seg2','sex','sgr1','sgr2','smc',\
# 'tri2','tuc2','tuc3','tuc4','tucv','umaj1','umaj2','umin1','vir1',\
# 'will'

# %%
# distance = [107.9,66,42,209,218,160,100,36.2,27.8,116,30,251,182,42,\
# 117.5,71,20,366,87,140,120,53,132,79,78,134,27.6,214,250,210,155,180,\
# 49.97,215,415,84.3,45,114,187,30,92,90,23,35,90,20,67,SMC,30,57,25,48,\
# 55,97.3,34.7,60,87,45           ]

# %%
# Distance and los velocity

names = ['aqr2','boo1','boo2','cvn1','cvn2',\
         'car1','car2','car3','col1','comb1','crat2',\
         'dra1','dra2','eri2','forn','grus1',\
         'herc','hor1','hya2','hyi1','leo1',\
         'leo2','leo4','leov','lmc','peg3',\
         'phe1','phe2','psc2','ret2','scu',\
         'seg1','seg2','sgr1','smc','tri2',\
         'tuc2','tuc3','umaj1','umaj2','umin1',\
         'will']

# %%
distance = [107.9, 66, 42, 218, 160,\
            100, 36.2, 27.8, 182, 42, 117.5,\
            71, 20, 366, 140, 120,\
            132, 79, 134, 27.6, 250,\
            210, 155, 180, 49.97, 215,\
            415, 84.3, 187, 30, 90,\
            23, 35, 20, 61.7, 30, \
            57, 25, 97.3, 34.7, 60,\
            45]

# %%
vlos = [-71.1, 101.8, -117, 30.9, -128.9,\
        229.1, 477.2, 284.6, 153.7,98.1, 87.5,\
        -291, -347.6, 75.6, 55.3, -140.5,\
        45.2, 112.8, 303.1, 80.4, 282.5,\
        78, 132.3, 173.3, 262.2, -223,\
        -21.2, -42, -226.5, 62.8, 111.4,\
        208.5, -40.2, 140, 145.6, -381.7,\
        -129.1, -102.3, -55.3, -116.5, -246.9,\
        -12.8]

# %%
# Distance and los velocity

r_names = ['aqr2','boo1','cvn1','cvn2',\
         'car1','col1','comb1','crat2',\
         'dra1','dra2','eri2','forn','grus1',\
         'herc','hor1','hya2','hyi1','leo1',\
         'leo2','leo4','leov','lmc','peg3',\
         'phe1','phe2','psc2','ret2','scu',\
         'seg1','seg2','sgr1','smc','tri2',\
         'tuc2','tuc3','umaj1','umaj2','umin1',\
         'will']

r_dist = [107.9, 66, 218, 160,\
            100, 182, 42, 117.5,\
            71, 20, 366, 140, 120,\
            132, 79, 134, 27.6, 250,\
            210, 155, 180, 49.97, 215,\
            415, 84.3, 187, 30, 90,\
            23, 35, 20, 61.7, 30, \
            57, 25, 97.3, 34.7, 60,\
            45]   

r_vlos = [-71.1, 101.8, -117, 30.9, -128.9,\
        229.1, ,98.1, 87.5,\
        -291, -347.6, 75.6, 55.3, -140.5,\
        45.2, 112.8, 303.1, 80.4, 282.5,\
        78, 132.3, 173.3, 262.2, -223,\
        -21.2, -42, -226.5, 62.8, 111.4,\
        208.5, -40.2, 140, 145.6, -381.7,\
        -129.1, -102.3, -55.3, -116.5, -246.9,\
        -12.8]

# %%
t_names = ['boo2',\
         'car1','comb1',\
         'dra2','grus1',\
         'hor1','hya2',\
         'peg3',\
         'phe1','phe2','psc2','ret2',\
         'seg1','seg2','tri2',\
         'tuc2','tuc3','umaj2',\
         'will']

t_dist = [42, \
            100, 42, \
            20, 120,\
            79, 134, \
            215,\
            415, 84.3, 187, 30, \
            23, 35, 30, \
            57, 25, 34.7, \
            45]   

t_vlos = [-117, \
        229.1, 98.1, \
        -347.6, -140.5, \
        112.8, 303.1, \
        -223,\
        -21.2, -42, -226.5, 62.8, \
        208.5, -40.2, -381.7,\
        -129.1, -102.3, -116.5, \
        -12.8]

# %%
print(len(names))
print(len(distance))
print(len(vlos))
# Out:
# 41
# 41
# 41

# %%
lg_mw = ['hya2','peg3','sgr2','tri2','tuc2']
lg_d = [134,215,67,30,57]
lg_v = [303.1,-223,-177.3,-381.7,-129.1] # sag2 comes from NK MCMC
lmc_as = ['hor1','phe2','ret2']
lmc_d = [79,84.3,30]
lmc_v = [112.8,-42,62.8]

# %%
acLMC_d = 49.97
acLMC_v = 262.2

acSMC_d = 61.7
acSMC_v = 145.6

# %%
fig, ax = plt.subplots()

ax.scatter(distance,vlos,s=10)
ax.scatter(lg_d,lg_v,marker='o')
ax.scatter(lmc_d,lmc_v,marker='o')

plt.show()

# %%
from matplotlib import rcParams
rcParams["font.family"] = "serif"

# %%
fig, ax = plt.subplots(figsize=(13,13))

ax.scatter(distance,vlos,s=60,marker='^',color='darkgrey',label='MW Dwarf Satellites')
ax.scatter(t_dist,t_vlos,marker='*',label='HST-GO 14734',s=150,color='navy')
ax.scatter(lg_d,lg_v,marker='d',label='Long-Term MW',s=150,color='mediumseagreen')
ax.scatter(lmc_d,lmc_v,marker='d',label='LMC Associated',s=150,color='mediumpurple')
ax.plot(acLMC_d,acLMC_v,marker='o',ms=20,color='black')
ax.plot(acSMC_d,acSMC_v,marker='o',ms=20,color='mediumpurple')
ax.text(67,140,"SMC",size=20)
ax.text(55,260,"LMC",size=20)

ax.set_xlim(0,255)
ax.legend(fontsize=25)
ax.set_xlabel('Distance (kpc)',fontsize=40)
ax.set_ylabel('Radial Velocity (km/s)',fontsize=40)
ax.tick_params(axis='both', which='major', labelsize=20)

plt.show()
# plt.savefig('catRawMags20Aug/vLOSplot.png',dpi=600,bbox_inches='tight')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/hr8jz/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-16-22b7a653d223>", line 19, in <module>
#     plt.savefig('catRawMags20Aug/vLOSplot.png',dpi=600,bbox_inches='tight')
#   File "/Users/hr8jz/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 729, in savefig
#     res = fig.savefig(*args, **kwargs)
#   File "/Users/hr8jz/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py", line 2180, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/Users/hr8jz/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py", line 2091, in print_figure
#     **kwargs)
# ...

# %%
# vlos = [-71.1,101.8,-117,197.5,boo4,30.9,-128.9,car1,477.2,284.6,\
# cen1,cet2,cet3,col1miss,98.1,87.5,dra1,-347.6,75.6,eri3miss,55.3,-140.5,\
# grus2miss,45.2,112.8,hor2miss,303.1,80.4,ind2,leo1,leo2,132.3,173.3,lmc,-223,\
# 21.2,-42,pic2,pic1miss,-226.5,62.8,ret3miss,scu,208.5,-40.2,sex,sgr1,sgr2,smc,\
# -381.7,-129.1,-102.3,tuc4miss,tuc5,-55.3,-116.5,umin1,vir1,-12.8]
