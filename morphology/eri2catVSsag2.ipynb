# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cat = np.genfromtxt('../catRawMags20Aug/catDir_SAGITTARIUS-II/sgCut_SAGITTARIUS-II.dat',names=True)

# %%
eri = np.genfromtxt('eri2.cat',names=True)
# eri_x = eri['x']
# eri_y = erit['y']

# %%
# flag = eri['flag']
# m814 = eri['m814']
# m606 = eri['m606']
# good = ((flag & 1) == 0) & ((flag & 2) == 0) & ((flag & 4) == 0) & ((flag & 8) == 0) & ((flag & 1024) == 0) & (m814 < 29.15) & (m606 < 28.70) & (m606-m814 < 0)
# good_indices = [i for i, test in enumerate(good) if test]
# eri_good[good_indices]

# %%
rand_ind = np.random.choice(len(eri),int(0.0625*len(eri)),\
                            replace=False)

# %%
eri_short = eri[rand_ind]

# %%
plt.hist(cat['magZPT_f606w'])

plt.show()

# %%
plt.hist(eri_short['m606'])

plt.show()

# %%
plt.hist(cat['magZPTerr_f606w'])

plt.show()

# %%
plt.hist(eri_short['dm606'])

plt.show()

# %%
plt.hist(eri_short['dm814'])

plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(eri_short['x'],eri_short['y'],s=5)

plt.show()

# %%
sag_x0 = 2386.25
sag_y0 = 2224.53

fig, ax = plt.subplots()

ax.scatter(cat['xt1_f606w'],cat['yt1_f606w'],s=5)
ax.plot(sag_x0,sag_y0,marker='o',color='red')

plt.show()
