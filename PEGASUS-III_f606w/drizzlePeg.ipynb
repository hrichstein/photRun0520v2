# %%
import numpy as np
import os
import shutil
from drizzlepac import tweakreg
from drizzlepac import astrodrizzle
# Out:
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       imagefindpars           mapreg              photeq
#      pixreplace           pixtopix            pixtosky        refimagefindpars
#      resetbits          runastrodriz          skytopix           tweakback
#       tweakreg           updatenpol

# %%
from drizzlepac import staticMask, sky, createMedian, ablot, drizCR, adrizzle

# %%
astrodrizzle.AstroDrizzle(['jdan46nxq_flc.fits', 
                           'jdan46nsq_flc.fits', 
                           'jdan46o1q_flc.fits'],
                          clean=True,\
                configobj='../../Hannah_Data/astrodrizzle_new.cfg')
# Out:
# Setting up logfile :  astrodrizzle.log
# AstroDrizzle Version 3.0.2 (2019-05-28 16:51:22 -0400) started at: 09:09:28.287 (28/04/2021)
#
# ==== Processing Step  Initialization  started at  09:09:28.290 (28/04/2021)
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 336.103933841561  5.4115808192529995
# CRPIX : 2109.5  2121.5
# CD1_1 CD1_2  : 4.02861748316152e-06  -1.3291782263574235e-05
# CD2_1 CD2_2  : -1.3291782263574235e-05  -4.02861748316152e-06
# NAXIS : 4219  4243
# ********************************************************************************
# *
# *  Estimated memory usage:  up to 1075 Mb.
# *  Output image size:       4219 X 4243 pixels.
# *  Output image file:       ~ 204 Mb.
# *  Cores available:         4
# *
# ********************************************************************************
# ==== Processing Step  Initialization  finished at  09:09:31.590 (28/04/2021)
#
# ...
