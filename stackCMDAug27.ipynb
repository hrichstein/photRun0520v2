# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams["font.family"] = "serif"

# %%
all = np.genfromtxt('catRawMags20Aug/sg_TCcutAll.dat',names=True)
lmc = np.genfromtxt('catRawMags20Aug/sgCut_LMC.dat',names=True)
mw = np.genfromtxt('catRawMags20Aug/sgCut_MW.dat',names=True)

# %%
fm12a04a12 = np.genfromtxt('/Users/hr8jz/Box Sync/Research/iso2/fm120alp04age120.iso')

# %%
fm15a04a11 = np.genfromtxt('/Users/hr8jz/Box Sync/Research/iso2/fm150alp04age110.iso')

# %%
fm15a04a12 = np.genfromtxt('/Users/hr8jz/Box Sync/Research/iso2/fm150alp04age120.iso')

# %%
fm20a04a12 = np.genfromtxt('/Users/hr8jz/Box Sync/Research/iso2/fm200alp04age120.iso')

# %%
fm22a04a12 = np.genfromtxt('/Users/hr8jz/Box Sync/Research/iso2/fm220alp04age120.iso')

# %%
fig,ax = plt.subplots(figsize=(13,13))


# ax.scatter(lmc['f606w']-lmc['f814w'],lmc['f606w'],s=5,color='silver')
ax.scatter(all['f606w']-all['f814w'],all['f606w'],s=5,color='silver')
# ax.scatter(fm12a04a11[:,4]-fm12a04a11[:,5],fm12a04a11[:,4])
# ax.scatter(fm15a04a11[:,4]-fm15a04a11[:,5],fm15a04a11[:,4],s=10)
# ax.scatter(fm20a04a13[:,4]-fm20a04a13[:,5]+0.04,fm20a04a13[:,4],s=10)
# ax.scatter(fm20a04a12[:,4]-fm20a04a12[:,5]+0.04,fm20a04a12[:,4],s=10)
# ax.plot(fm18a04a13[:,4]-fm18a04a13[:,5]+0.04,fm18a04a13[:,4],ls='-.',linewidth=5,color='mediumpurple',\
#        label=r'[Fe/H]=-1.8, [$\alpha$/H]=0.4, Age=13 Gyr')

ax.plot(fm20a04a12[:,4]-fm20a04a12[:,5]+0.04,fm20a04a12[:,4],ls='-.',linewidth=5,\
        color='navy',\
       label=r'[Fe/H]=-2.0, [$\alpha$/H]=0.4, Age=12 Gyr')

ax.set_ylim(6,-1.)
ax.set_xlim(-1.2,0)
ax.set_xlabel(r'M$_{F606W}$ - M$_{F814W}$',fontsize=40)
ax.set_ylabel(r'M$_{F606W}$',fontsize=40)
ax.tick_params(axis='both', which='major', labelsize=30)

ax.legend(fontsize=30)

# plt.show()
plt.savefig('stackedCMDposter.png',dpi=600,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(13,13))

ax.scatter(mw['f606w']-mw['f814w'],mw['f606w'],s=50,color='mediumseagreen',\
           marker='+',label='Long-Term MW',alpha=0.5)
ax.scatter(lmc['f606w']-lmc['f814w'],lmc['f606w'],s=20,color='mediumpurple',label='LMC Associated')
# ax.scatter(all['f606w']-all['f814w'],all['f606w'],s=5,color='silver')
# ax.scatter(fm12a04a11[:,4]-fm12a04a11[:,5],fm12a04a11[:,4])
# ax.scatter(fm15a04a11[:,4]-fm15a04a11[:,5],fm15a04a11[:,4],s=10)
# ax.scatter(fm15a04a12[:,4]-fm15a04a12[:,5],fm15a04a12[:,4],s=10)
# ax.plot(fm18a04a12[:,4]-fm18a04a12[:,5]+0.04,fm18a04a12[:,4],ls='--',linewidth=5,color='mediumpurple',\
#        label=r'[Fe/H]=-1.8, [$\alpha$/H]=0.4, Age=12 Gyr')
# ax.plot(fm22a04a12[:,4]-fm22a04a12[:,5]+0.04,fm22a04a12[:,4],ls='--',linewidth=5,\
#        label=r'[Fe/H]=-2.0, [$\alpha$/H]=0.4, Age=12 Gyr')
ax.plot(fm20a04a12[:,4]-fm20a04a12[:,5]+0.04,fm20a04a12[:,4],ls='--',linewidth=5,\
       label=r'[Fe/H]=-2.0, [$\alpha$/H]=0.4, Age=12 Gyr',color='lime')
ax.plot(fm16a04a12[:,4]-fm16a04a12[:,5]+0.04,fm16a04a12[:,4],ls='--',linewidth=5,\
       label=r'[Fe/H]=-1.6, [$\alpha$/H]=0.4, Age=12 Gyr',color='blueviolet')
# ax.plot(fm12a04a12[:,4]-fm12a04a12[:,5]+0.04,fm12a04a12[:,4],ls='-.',linewidth=5,color='mediumpurple',\
#        label=r'[Fe/H]=-1.2, [$\alpha$/H]=0.4, Age=12 Gyr')

ax.set_ylim(6,-1.)
ax.set_xlim(-1.2,0)
ax.set_xlabel(r'M$_{F606W}$ - M$_{F814W}$',fontsize=40)
ax.set_ylabel(r'M$_{F606W}$',fontsize=40)
ax.tick_params(axis='both', which='major', labelsize=30)

ax.legend(fontsize=30)

# plt.show()
plt.savefig('LMC-MWposter.png',dpi=600,bbox_inches='tight')

# %%
fm18a04a13 = np.genfromtxt('/Users/hr8jz/Box Sync/Research/iso2/fm180alp04age130.iso')

# %%
fm18a04a12 = np.genfromtxt('/Users/hr8jz/Box Sync/Research/iso2/fm180alp04age120.iso')

# %%
fm20a04a13 = np.genfromtxt('/Users/hr8jz/Box Sync/Research/iso2/fm200alp04age130.iso')

# %%
fm19a04a13 = np.genfromtxt('/Users/hr8jz/Box Sync/Research/iso2/fm190alp04age130.iso')

# %%
fm16a04a12 = np.genfromtxt('/Users/hr8jz/Box Sync/Research/iso2/fm160alp04age120.iso')

# %%
fig,ax = plt.subplots(figsize=(13,13))

ax.scatter(mw['f606w']-mw['f814w'],mw['f606w'],s=5,color='silver')
# ax.scatter(all['f606w']-all['f814w'],all['f606w'],s=5,color='silver')
# ax.scatter(fm12a04a11[:,4]-fm12a04a11[:,5],fm12a04a11[:,4])
# ax.scatter(fm15a04a11[:,4]-fm15a04a11[:,5],fm15a04a11[:,4],s=10)
# ax.scatter(fm15a04a12[:,4]-fm15a04a12[:,5],fm15a04a12[:,4],s=10)
# ax.plot(fm18a04a13[:,4]-fm18a04a13[:,5],fm18a04a13[:,4],ls='-.',linewidth=5,\
#        label=r'[Fe/H]=-1.8, [$\alpha$/H]=0.4, Age=13 Gyr')
ax.plot(fm20a04a13[:,4]-fm20a04a13[:,5]+0.04,fm20a04a13[:,4],ls='-.',linewidth=5,\
       label=r'[Fe/H]=-2.0, [$\alpha$/H]=0.4, Age=13 Gyr')
# ax.plot(fm19a04a13[:,4]-fm19a04a13[:,5],fm19a04a13[:,4],ls='-.',linewidth=5,\
#        label=r'[Fe/H]=-1.9, [$\alpha$/H]=0.4, Age=13 Gyr')
# ax.plot(fm16a04a13[:,4]-fm16a04a13[:,5]+0.04,fm16a04a13[:,4],ls='-.',linewidth=5,\
#        label=r'[Fe/H]=-1.6, [$\alpha$/H]=0.4, Age=13 Gyr')
# ax.plot(fm12a04a12[:,4]-fm12a04a12[:,5],fm12a04a12[:,4],ls='-.',linewidth=5,color='mediumpurple',\
#        label=r'[Fe/H]=-1.2, [$\alpha$/H]=0.4, Age=13 Gyr')

ax.set_ylim(6,-1.)
ax.set_xlim(-1.2,0)
ax.set_xlabel(r'M$_{F606W}$ - M$_{F814W}$',fontsize=40)
ax.set_ylabel(r'M$_{F606W}$',fontsize=40)
ax.tick_params(axis='both', which='major', labelsize=30)

ax.legend(fontsize=30)

plt.show()
