# %%
import numpy as np
import os
import shutil
from drizzlepac import tweakreg
from drizzlepac import astrodrizzle
# Out:
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       imagefindpars           mapreg              photeq
#      pixreplace           pixtopix            pixtosky        refimagefindpars
#      resetbits          runastrodriz          skytopix           tweakback
#       tweakreg           updatenpol

# %%
from drizzlepac import staticMask, sky, createMedian, ablot, drizCR, adrizzle

# %%
from astropy.io import fits

# %%
hdu1 = fits.open('jdan47m9q_flc.fits')

# %%
hdu1[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# ORIGIN  = 'HSTIO/CFITSIO March 2010' / FITS file originator
# DATE    = '2018-10-27' / date this file was written (yyyy-mm-dd)
# NEXTEND =                   24 / Number of standard extensions
# FILENAME= 'jdan47m9q_flc.fits' / name of file
# FILETYPE= 'SCI      '          / type of data found in data file
#
# TELESCOP= 'HST'                / telescope used to acquire data
# INSTRUME= 'ACS   '             / identifier for instrument used to acquire data
# EQUINOX =               2000.0 / equinox of celestial coord. system
#
# ...

# %%
# hdr = hdul[0].header
# hdr['IDCTAB'] = 'jref$4bb1536mj_idc.fits'

# %%
# arr = np.array(['jdan47m9q_flc.fits', 
#                            'jdan47myq_flc.fits', 
#                            'jdan47n2q_flc.fits',
#                           'jdan47n6q_flc.fits'])

# %%
f1 = 'jdan47m9q_flc.fits'
f2 = 'jdan47myq_flc.fits'
f3 = 'jdan47n2q_flc.fits'
f4 = 'jdan47n6q_flc.fits'

# %%
# import glob
# import os

# %%
# from stwcs import updatewcs

# %%
# input_images = sorted(glob.glob('*flc.fits'))
# _ = updatewcs.updatewcs(input_images)

# %%
tweakreg.TweakReg([f1,f2,f3,f4],updatehdr=True)
# Out:
# Setting up logfile :  tweakreg.log
# TweakReg Version 1.4.7(18-April-2018) started at: 12:32:55.77 (28/04/2021)
#
# Version Information
# --------------------
# Python Version [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# 3.6.10 |Anaconda, Inc.| (default, Jan  7 2020, 15:01:53)
# numpy Version -> 1.18.1
# astropy Version -> 4.0
# stwcs Version -> 1.5.3
#
# Finding shifts for:
#     jdan47m9q_flc.fits
#     jdan47myq_flc.fits
#     jdan47n2q_flc.fits
#     jdan47n6q_flc.fits
#
# ===  Source finding for image 'jdan47m9q_flc.fits':
#   #  Source finding for 'jdan47m9q_flc.fits', EXT=('SCI', 1) started at: 12:32:57.477 (28/04/2021)
#      Found 40043 objects.
#   #  Source finding for 'jdan47m9q_flc.fits', EXT=('SCI', 2) started at: 12:33:01.134 (28/04/2021)
#      Found 41643 objects.
# ===  FINAL number of objects in image 'jdan47m9q_flc.fits': 81686
#
# ===  Source finding for image 'jdan47myq_flc.fits':
# ...

# %%
astrodrizzle.AstroDrizzle([f1,f2,f3,f4],\
                          clean=True,final_rot=0.0,\
                configobj='../../Hannah_Data/astrodrizzle_new.cfg')
# Out:
# Setting up logfile :  astrodrizzle.log
# AstroDrizzle Version 3.0.2 (2019-05-28 16:51:22 -0400) started at: 09:50:13.930 (28/04/2021)
#
# ==== Processing Step  Initialization  started at  09:50:13.934 (28/04/2021)
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 336.1039445286259  5.411604410571842
# CRPIX : 2641.2835974605287  2633.2368096342034
# CD1_1 CD1_2  : -1.388888888888889e-05  0.0
# CD2_1 CD2_2  : 0.0  1.388888888888889e-05
# NAXIS : 5282  5264
# ********************************************************************************
# *
# *  Estimated memory usage:  up to 1528 Mb.
# *  Output image size:       5282 X 5264 pixels.
# *  Output image file:       ~ 318 Mb.
# *  Cores available:         4
# *
# ********************************************************************************
# ==== Processing Step  Initialization  finished at  09:50:16.675 (28/04/2021)
#
# ==== Processing Step  Static Mask  started at  09:50:16.681 (28/04/2021)
# ...
